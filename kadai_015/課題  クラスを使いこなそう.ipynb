# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age
  def printinfo(self):
      print(self.name)
      print(self.age)
human = Human("木村拓哉" , 55)
human.printinfo()
# Out:
# 木村拓哉
# 55
