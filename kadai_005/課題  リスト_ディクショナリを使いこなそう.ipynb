# %%
array = ["月曜日は晴れです", "火曜日は雨です","水曜日は晴れです", "木曜日は晴れです","金曜日は曇りです", "土曜日は曇りのち雨です","日曜日は雷雨です"]
dictionary = {mon:"晴れ", tue:"雨", wed: "晴れ", thu:"晴れ", fri:"曇り", sat:"曇りのち雨", sun:"雷雨"}
print(array[2])
print(dictionary["wed"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_930/3227454728.py in <cell line: 0>()
#       1 array = ["月曜日は晴れです", "火曜日は雨です","水曜日は晴れです", "木曜日は晴れです","金曜日は曇りです", "土曜日は曇りのち雨です","日曜日は雷雨です"]
# ----> 2 dictionary = {mon:"晴れ", tue:"雨", wed: "晴れ", thu:"晴れ", fri:"曇り", sat:"曇りのち雨", sun:"雷雨"}
#       3 print(array[2])
#       4 print(dictionary["wed"])
#
# NameError: name 'mon' is not defined

# %%
array = ["月曜日は晴れです", "火曜日は雨です","水曜日は晴れです", "木曜日は晴れです","金曜日は曇りです", "土曜日は曇りのち雨です","日曜日は雷雨です"]
dictionary = {"mon":"晴れ", "tue":"雨", "wed": "晴れ", "thu":"晴れ", "fri":"曇り", "sat":"曇りのち雨", "sun":"雷雨"}
print(array[2])
print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
